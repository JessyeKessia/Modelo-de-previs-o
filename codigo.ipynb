# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# %%
# Caminho do CSV criado anteriormente
caminho_csv = "data/sorvete_temperatura_vendas.csv"

# 1. Ler os dados do CSV
df = pd.read_csv(caminho_csv)

print(df.columns)
# Out:
# Index(['Data', 'Temperatura (C)', 'Vendas (unidades)'], dtype='object')

# %%
# 2. Preparar os dados
X = df[["Temperatura (C)"]]   # Feature
y = df["Vendas (unidades)"]   # Target

# %%
# 3. Treinar o modelo de regressão linear
model = LinearRegression()
model.fit(X, y)
# Out:
# LinearRegression()

# %%
# 4. Fazer a previsão de vendas com base na temperatura
df["Estoque Previsto"] = model.predict(X).round().astype(int)

# %%
# 5. Mostrar a equação da previsão
print(f"Equação: vendas = {model.coef_[0]:.2f} * temperatura + {model.intercept_:.2f}")
print("\nPrevisões de estoque por dia:\n")
print(df[["Data", "Temperatura (C)", "Estoque Previsto"]])
# Out:
# Equação: vendas = 6.99 * temperatura + -55.44
#
# Previsões de estoque por dia:
#
#          Data  Temperatura (C)  Estoque Previsto
# 0  2025-04-01               28               140
# 1  2025-04-02               30               154
# 2  2025-04-03               25               119
# 3  2025-04-04               35               189
# 4  2025-04-05               32               168
# 5  2025-04-06               27               133
# 6  2025-04-07               33               175
# 7  2025-04-08               26               126
# 8  2025-04-09               31               161
# 9  2025-04-10               29               147

# %%
# 6. Visualizar graficamente
plt.plot(df["Data"], df["Estoque Previsto"], marker='o', label="Estoque Previsto")
plt.plot(df["Data"], df["Vendas (unidades)"], marker='x', label="Vendas Reais")
plt.xticks(rotation=45)
plt.xlabel("Data")
plt.ylabel("Unidades de Sorvete")
plt.title("Previsão de Estoque de Sorvete por Temperatura")
plt.legend()
plt.tight_layout()
plt.grid(True)
plt.show()
